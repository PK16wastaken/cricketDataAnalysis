# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cricket_data = pd.read_csv('cricket_data.csv.csv')

# %%
cricket_data
# Out:
#             Team 1        Team 2       Winner     Margin  \
# 0            India      Pakistan        drawn        NaN
# 1            India      Pakistan        drawn        NaN
# 2            India      Pakistan        India  6 wickets
# 3         Pakistan         India     Pakistan   341 runs
# 4         Pakistan         India        drawn        NaN
# ...            ...           ...          ...        ...
# 7788     Australia  ICC World XI    Australia   210 runs
# 7789     Australia  ICC World XI    Australia   156 runs
# 7790     Australia  ICC World XI    Australia    55 runs
# 7791     Australia  ICC World XI    Australia    93 runs
# 7792  ICC World XI   West Indies  West Indies    72 runs
#
#                      Ground          Match Date    Scorecard Format
# 0                 Bengaluru      Dec 8-12, 2007  Test # 1852  Test
# 1              Eden Gardens  Nov 30-Dec 4, 2007  Test # 1850  Test
# 2                     Delhi     Nov 22-26, 2007  Test # 1849  Test
# 3                   Karachi  Jan 29-Feb 1, 2006  Test # 1783  Test
# 4                Faisalabad     Jan 21-25, 2006  Test # 1782  Test
# ...                     ...                 ...          ...    ...
# 7788                 Sydney     Oct 14-17, 2005  Test # 1768  Test
# 7789  Melbourne (Docklands)         Oct 9, 2005   ODI # 2284   ODI
# 7790  Melbourne (Docklands)         Oct 7, 2005   ODI # 2283   ODI
# 7791  Melbourne (Docklands)         Oct 5, 2005   ODI # 2282   ODI
# 7792                 Lord's        May 31, 2018   T20I # 666  T20I
#
# [7793 rows x 8 columns]

# %%
cricket_data = cricket_data.dropna()

# %%
cricket_data['Match Date']
# Out:
# 2          Nov 22-26, 2007
# 3       Jan 29-Feb 1, 2006
# 6          Mar 24-28, 2005
# 7          Mar 16-20, 2005
# 9          Apr 13-16, 2004
#                ...
# 7788       Oct 14-17, 2005
# 7789           Oct 9, 2005
# 7790           Oct 7, 2005
# 7791           Oct 5, 2005
# 7792          May 31, 2018
# Name: Match Date, Length: 6755, dtype: object

# %%
cricket_data['Match Date'].str.contains("2000")
# Out:
# 2       False
# 3       False
# 6       False
# 7       False
# 9       False
#         ...
# 7788    False
# 7789    False
# 7790    False
# 7791    False
# 7792    False
# Name: Match Date, Length: 6755, dtype: bool

# %%
cricket_data['Year'] = cricket_data['Match Date'].str[-4:]
# Out:
# C:\Users\Pranay Krishna\AppData\Local\Temp\ipykernel_18136\720064217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cricket_data['Year'] = cricket_data['Match Date'].str[-4:]

# %%
cricket_data
# Out:
#             Team 1        Team 2       Winner           Margin  \
# 2            India      Pakistan        India        6 wickets
# 3         Pakistan         India     Pakistan         341 runs
# 6            India      Pakistan     Pakistan         168 runs
# 7            India      Pakistan        India         195 runs
# 9         Pakistan         India        India  inns & 131 runs
# ...            ...           ...          ...              ...
# 7788     Australia  ICC World XI    Australia         210 runs
# 7789     Australia  ICC World XI    Australia         156 runs
# 7790     Australia  ICC World XI    Australia          55 runs
# 7791     Australia  ICC World XI    Australia          93 runs
# 7792  ICC World XI   West Indies  West Indies          72 runs
#
#                      Ground          Match Date    Scorecard Format  Year
# 2                     Delhi     Nov 22-26, 2007  Test # 1849  Test   2007
# 3                   Karachi  Jan 29-Feb 1, 2006  Test # 1783  Test   2006
# 6                 Bengaluru     Mar 24-28, 2005  Test # 1743  Test   2005
# 7              Eden Gardens     Mar 16-20, 2005  Test # 1741  Test   2005
# 9                Rawalpindi     Apr 13-16, 2004  Test # 1697  Test   2004
# ...                     ...                 ...          ...    ...   ...
# 7788                 Sydney     Oct 14-17, 2005  Test # 1768  Test   2005
# 7789  Melbourne (Docklands)         Oct 9, 2005   ODI # 2284   ODI   2005
# 7790  Melbourne (Docklands)         Oct 7, 2005   ODI # 2283   ODI   2005
# 7791  Melbourne (Docklands)         Oct 5, 2005   ODI # 2282   ODI   2005
# 7792                 Lord's        May 31, 2018   T20I # 666  T20I   2018
#
# [6755 rows x 9 columns]

# %%
cricket_data
# Out:
#             Team 1        Team 2       Winner           Margin  \
# 2            India      Pakistan        India        6 wickets
# 3         Pakistan         India     Pakistan         341 runs
# 6            India      Pakistan     Pakistan         168 runs
# 7            India      Pakistan        India         195 runs
# 9         Pakistan         India        India  inns & 131 runs
# ...            ...           ...          ...              ...
# 7788     Australia  ICC World XI    Australia         210 runs
# 7789     Australia  ICC World XI    Australia         156 runs
# 7790     Australia  ICC World XI    Australia          55 runs
# 7791     Australia  ICC World XI    Australia          93 runs
# 7792  ICC World XI   West Indies  West Indies          72 runs
#
#                      Ground          Match Date    Scorecard Format  Year
# 2                     Delhi     Nov 22-26, 2007  Test # 1849  Test   2007
# 3                   Karachi  Jan 29-Feb 1, 2006  Test # 1783  Test   2006
# 6                 Bengaluru     Mar 24-28, 2005  Test # 1743  Test   2005
# 7              Eden Gardens     Mar 16-20, 2005  Test # 1741  Test   2005
# 9                Rawalpindi     Apr 13-16, 2004  Test # 1697  Test   2004
# ...                     ...                 ...          ...    ...   ...
# 7788                 Sydney     Oct 14-17, 2005  Test # 1768  Test   2005
# 7789  Melbourne (Docklands)         Oct 9, 2005   ODI # 2284   ODI   2005
# 7790  Melbourne (Docklands)         Oct 7, 2005   ODI # 2283   ODI   2005
# 7791  Melbourne (Docklands)         Oct 5, 2005   ODI # 2282   ODI   2005
# 7792                 Lord's        May 31, 2018   T20I # 666  T20I   2018
#
# [6755 rows x 9 columns]

# %%
cricket_data['Year'] = pd.to_datetime(cricket_data['Year'])
# Out:
# C:\Users\Pranay Krishna\AppData\Local\Temp\ipykernel_18136\713129997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cricket_data['Year'] = pd.to_datetime(cricket_data['Year'])

# %%
cricket_data['year_only'] = cricket_data['Year'].dt.year
# Out:
# C:\Users\Pranay Krishna\AppData\Local\Temp\ipykernel_18136\1277241425.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cricket_data['year_only'] = cricket_data['Year'].dt.year

# %%
cricket_data
# Out:
#             Team 1        Team 2       Winner           Margin  \
# 2            India      Pakistan        India        6 wickets
# 3         Pakistan         India     Pakistan         341 runs
# 6            India      Pakistan     Pakistan         168 runs
# 7            India      Pakistan        India         195 runs
# 9         Pakistan         India        India  inns & 131 runs
# ...            ...           ...          ...              ...
# 7788     Australia  ICC World XI    Australia         210 runs
# 7789     Australia  ICC World XI    Australia         156 runs
# 7790     Australia  ICC World XI    Australia          55 runs
# 7791     Australia  ICC World XI    Australia          93 runs
# 7792  ICC World XI   West Indies  West Indies          72 runs
#
#                      Ground          Match Date    Scorecard Format  \
# 2                     Delhi     Nov 22-26, 2007  Test # 1849  Test
# 3                   Karachi  Jan 29-Feb 1, 2006  Test # 1783  Test
# 6                 Bengaluru     Mar 24-28, 2005  Test # 1743  Test
# 7              Eden Gardens     Mar 16-20, 2005  Test # 1741  Test
# 9                Rawalpindi     Apr 13-16, 2004  Test # 1697  Test
# ...                     ...                 ...          ...    ...
# 7788                 Sydney     Oct 14-17, 2005  Test # 1768  Test
# 7789  Melbourne (Docklands)         Oct 9, 2005   ODI # 2284   ODI
# 7790  Melbourne (Docklands)         Oct 7, 2005   ODI # 2283   ODI
# 7791  Melbourne (Docklands)         Oct 5, 2005   ODI # 2282   ODI
# 7792                 Lord's        May 31, 2018   T20I # 666  T20I
#
#            Year  year_only
# 2    2007-01-01       2007
# 3    2006-01-01       2006
# 6    2005-01-01       2005
# 7    2005-01-01       2005
# 9    2004-01-01       2004
# ...         ...        ...
# 7788 2005-01-01       2005
# 7789 2005-01-01       2005
# 7790 2005-01-01       2005
# 7791 2005-01-01       2005
# 7792 2018-01-01       2018
#
# [6755 rows x 10 columns]

# %%
cricket_data = cricket_data.sort_values(by='year_only')

# %%
cricket_data
# Out:
#          Team 1       Team 2       Winner      Margin         Ground  \
# 3945  Australia      England    Australia     45 runs      Melbourne
# 3944  Australia      England      England   4 wickets      Melbourne
# 3943  Australia      England    Australia  10 wickets      Melbourne
# 3942    England    Australia      England   5 wickets       The Oval
# 3937    England    Australia    Australia      7 runs       The Oval
# ...         ...          ...          ...         ...            ...
# 2300      India      England        India    150 runs       Wankhede
# 4636  Sri Lanka    Australia    Sri Lanka     49 runs  Colombo (RPS)
# 1684  Australia        India    Australia   6 wickets         Sydney
# 804    Pakistan  New Zealand  New Zealand   5 wickets        Karachi
# 6683   Zimbabwe      Ireland     Zimbabwe   3 wickets         Harare
#
#               Match Date    Scorecard Format       Year  year_only
# 3945     Mar 15-19, 1877     Test # 1  Test  1877-01-01       1877
# 3944  Mar 31-Apr 4, 1877     Test # 2  Test  1877-01-01       1877
# 3943       Jan 2-4, 1879     Test # 3  Test  1879-01-01       1879
# 3942       Sep 6-8, 1880     Test # 4  Test  1880-01-01       1880
# 3937     Aug 28-29, 1882     Test # 9  Test  1882-01-01       1882
# ...                  ...          ...    ...        ...        ...
# 2300         Feb 2, 2025  T20I # 3086  T20I  2025-01-01       2025
# 4636        Feb 12, 2025   ODI # 4831   ODI  2025-01-01       2025
# 1684       Jan 3-5, 2025  Test # 2575  Test  2025-01-01       2025
# 804         Feb 14, 2025   ODI # 4838   ODI  2025-01-01       2025
# 6683        Feb 23, 2025  T20I # 3101  T20I  2025-01-01       2025
#
# [6755 rows x 10 columns]

# %%
start_date = 2020  # Start date of your range
end_date = 2025    # End date of your range

decade2020 = cricket_data.loc[(cricket_data['year_only'] >= start_date) & (cricket_data['year_only'] <= end_date)]

# %%
decade2020
# Out:
#             Team 1       Team 2       Winner           Margin         Ground  \
# 6097  South Africa      England      England           2 runs         Durban
# 5481    Bangladesh     Zimbabwe   Bangladesh  inns & 106 runs         Mirpur
# 1656      Pakistan     Zimbabwe     Pakistan        8 wickets     Rawalpindi
# 1657      Pakistan     Zimbabwe     Pakistan        8 wickets     Rawalpindi
# 6095  South Africa      England      England        5 wickets      Cape Town
# ...            ...          ...          ...              ...            ...
# 2300         India      England        India         150 runs       Wankhede
# 4636     Sri Lanka    Australia    Sri Lanka          49 runs  Colombo (RPS)
# 1684     Australia        India    Australia        6 wickets         Sydney
# 804       Pakistan  New Zealand  New Zealand        5 wickets        Karachi
# 6683      Zimbabwe      Ireland     Zimbabwe        3 wickets         Harare
#
#            Match Date    Scorecard Format       Year  year_only
# 6097     Feb 14, 2020  T20I # 1041  T20I  2020-01-01       2020
# 5481  Feb 22-25, 2020  Test # 2386  Test  2020-01-01       2020
# 1656     Nov 10, 2020  T20I # 1107  T20I  2020-01-01       2020
# 1657      Nov 8, 2020  T20I # 1106  T20I  2020-01-01       2020
# 6095     Nov 27, 2020  T20I # 1109  T20I  2020-01-01       2020
# ...               ...          ...    ...        ...        ...
# 2300      Feb 2, 2025  T20I # 3086  T20I  2025-01-01       2025
# 4636     Feb 12, 2025   ODI # 4831   ODI  2025-01-01       2025
# 1684    Jan 3-5, 2025  Test # 2575  Test  2025-01-01       2025
# 804      Feb 14, 2025   ODI # 4838   ODI  2025-01-01       2025
# 6683     Feb 23, 2025  T20I # 3101  T20I  2025-01-01       2025
#
# [985 rows x 10 columns]

# %%
start_date = 2010  # Start date of your range
end_date = 2019  # End date of your range

decade2010 = cricket_data.loc[(cricket_data['year_only'] >= start_date) & (cricket_data['year_only'] <= end_date)]

# %%
decade2010
# Out:
#            Team 1        Team 2        Winner     Margin         Ground  \
# 430     Australia      Pakistan     Australia    34 runs     Gros Islet
# 5201   Bangladesh   New Zealand    Bangladesh     3 runs         Mirpur
# 5202   Bangladesh   New Zealand    Bangladesh     9 runs         Mirpur
# 7355  West Indies  South Africa  South Africa   163 runs  Port of Spain
# 5117   Bangladesh       England       England    45 runs     Chattogram
# ...           ...           ...           ...        ...            ...
# 3388  Afghanistan       Ireland       Ireland  4 wickets       Dehradun
# 3390  Afghanistan       Ireland   Afghanistan  5 wickets       Dehradun
# 3423  Afghanistan       Ireland   Afghanistan    84 runs       Dehradun
# 3386  Afghanistan       Ireland       Ireland  5 wickets       Dehradun
# 3422  Afghanistan       Ireland   Afghanistan    32 runs       Dehradun
#
#            Match Date    Scorecard Format       Year  year_only
# 430       May 2, 2010   T20I # 156  T20I  2010-01-01       2010
# 5201     Oct 17, 2010   ODI # 3058   ODI  2010-01-01       2010
# 5202     Oct 14, 2010   ODI # 3056   ODI  2010-01-01       2010
# 7355  Jun 10-13, 2010  Test # 1960  Test  2010-01-01       2010
# 5117      Mar 5, 2010   ODI # 2968   ODI  2010-01-01       2010
# ...               ...          ...    ...        ...        ...
# 3388      Mar 5, 2019   ODI # 4105   ODI  2019-01-01       2019
# 3390     Feb 28, 2019   ODI # 4100   ODI  2019-01-01       2019
# 3423     Feb 23, 2019   T20I # 746  T20I  2019-01-01       2019
# 3386     Mar 10, 2019   ODI # 4110   ODI  2019-01-01       2019
# 3422     Feb 24, 2019   T20I # 747  T20I  2019-01-01       2019
#
# [1860 rows x 10 columns]

# %%
start_date = 2000  # Start date of your range
end_date = 2009  # End date of your range

decade2000 = cricket_data.loc[(cricket_data['year_only'] >= start_date) & (cricket_data['year_only'] <= end_date)]

decade2000
# Out:
#             Team 1        Team 2        Winner          Margin        Ground  \
# 3247         India      Zimbabwe         India       7 wickets         Delhi
# 1065      Pakistan  South Africa  South Africa       3 wickets       Sharjah
# 5898  South Africa       England  South Africa  inns & 37 runs     Cape Town
# 7158      Zimbabwe   New Zealand   New Zealand       8 wickets        Harare
# 1064      Pakistan  South Africa      Pakistan         67 runs       Sharjah
# ...            ...           ...           ...             ...           ...
# 331      Australia      Pakistan      Pakistan       4 wickets  Dubai (DICS)
# 330      Australia      Pakistan     Australia       6 wickets  Dubai (DICS)
# 329      Australia      Pakistan     Australia         27 runs     Abu Dhabi
# 4011       England     Australia     Australia       7 wickets        Lord's
# 4231     Australia   New Zealand   New Zealand       6 wickets     Melbourne
#
#            Match Date    Scorecard Format       Year  year_only
# 3247  Nov 18-22, 2000  Test # 1515  Test  2000-01-01       2000
# 1065     Mar 24, 2000   ODI # 1579   ODI  2000-01-01       2000
# 5898    Jan 2-5, 2000  Test # 1482  Test  2000-01-01       2000
# 7158  Sep 19-23, 2000  Test # 1511  Test  2000-01-01       2000
# 1064     Mar 28, 2000   ODI # 1582   ODI  2000-01-01       2000
# ...               ...          ...    ...        ...        ...
# 331      Apr 22, 2009   ODI # 2845   ODI  2009-01-01       2009
# 330      Apr 24, 2009   ODI # 2846   ODI  2009-01-01       2009
# 329      Apr 27, 2009   ODI # 2847   ODI  2009-01-01       2009
# 4011     Sep 12, 2009   ODI # 2888   ODI  2009-01-01       2009
# 4231      Feb 6, 2009   ODI # 2816   ODI  2009-01-01       2009
#
# [1589 rows x 10 columns]

# %%
start_date = 1990  # Start date of your range
end_date = 1999  # End date of your range

decade1990 = cricket_data.loc[(cricket_data['year_only'] >= start_date) & (cricket_data['year_only'] <= end_date)]

decade1990
# Out:
#            Team 1       Team 2       Winner     Margin        Ground  \
# 2913        India    Sri Lanka    Sri Lanka  7 wickets        Margao
# 2914        India    Sri Lanka        India  6 wickets          Pune
# 2915        India    Sri Lanka        India    19 runs        Nagpur
# 2916        India    Sri Lanka    Sri Lanka  3 wickets       Sharjah
# 2912        India    Sri Lanka    Sri Lanka    36 runs       Cuttack
# ...           ...          ...          ...        ...           ...
# 2473        India  New Zealand  New Zealand  5 wickets    Nottingham
# 2474  New Zealand        India  New Zealand    70 runs  Christchurch
# 7106  New Zealand  West Indies  West Indies  7 wickets   Southampton
# 2475  New Zealand        India        India  5 wickets      Auckland
# 123         India     Pakistan     Pakistan   143 runs        Jaipur
#
#         Match Date   Scorecard Format       Year  year_only
# 2913   Dec 8, 1990   ODI # 648   ODI  1990-01-01       1990
# 2914   Dec 5, 1990   ODI # 646   ODI  1990-01-01       1990
# 2915   Dec 1, 1990   ODI # 644   ODI  1990-01-01       1990
# 2916  Apr 25, 1990   ODI # 623   ODI  1990-01-01       1990
# 2912  Dec 28, 1990   ODI # 658   ODI  1990-01-01       1990
# ...            ...         ...    ...        ...        ...
# 2473  Jun 12, 1999  ODI # 1480   ODI  1999-01-01       1999
# 2474  Jan 19, 1999  ODI # 1387   ODI  1999-01-01       1999
# 7106  May 24, 1999  ODI # 1460   ODI  1999-01-01       1999
# 2475  Jan 16, 1999  ODI # 1385   ODI  1999-01-01       1999
# 123   Mar 24, 1999  ODI # 1417   ODI  1999-01-01       1999
#
# [1065 rows x 10 columns]

# %%
start_date = 1980  # Start date of your range
end_date = 1989  # End date of your range

decade1980 = cricket_data.loc[(cricket_data['year_only'] >= start_date) & (cricket_data['year_only'] <= end_date)]

decade1980
# Out:
#            Team 1       Team 2       Winner     Margin        Ground  \
# 2519        India  New Zealand  New Zealand  3 wickets      Brisbane
# 5023    Australia  West Indies    Australia     9 runs        Sydney
# 4090    Australia      England      England  2 wickets        Sydney
# 6340      England  West Indies  West Indies  2 wickets    Nottingham
# 7128  New Zealand  West Indies  New Zealand   1 wicket  Christchurch
# ...           ...          ...          ...        ...           ...
# 907   New Zealand     Pakistan  New Zealand  8 wickets       Dunedin
# 3179        India  West Indies        India    37 runs       Sharjah
# 3178        India  West Indies  West Indies    20 runs         Delhi
# 3177        India  West Indies  West Indies  8 wickets      Wankhede
# 4979    Australia  West Indies    Australia    99 runs       Chennai
#
#           Match Date   Scorecard Format       Year  year_only
# 2519    Dec 21, 1980   ODI # 102   ODI  1980-01-01       1980
# 5023    Jan 18, 1980    ODI # 85   ODI  1980-01-01       1980
# 4090    Jan 14, 1980    ODI # 83   ODI  1980-01-01       1980
# 6340  Jun 5-10, 1980  Test # 880  Test  1980-01-01       1980
# 7128     Feb 6, 1980    ODI # 88   ODI  1980-01-01       1980
# ...              ...         ...    ...        ...        ...
# 907      Feb 6, 1989   ODI # 554   ODI  1989-01-01       1989
# 3179    Oct 16, 1989   ODI # 573   ODI  1989-01-01       1989
# 3178    Oct 23, 1989   ODI # 582   ODI  1989-01-01       1989
# 3177    Oct 30, 1989   ODI # 591   ODI  1989-01-01       1989
# 4979    Oct 21, 1989   ODI # 578   ODI  1989-01-01       1989
#
# [641 rows x 10 columns]

# %%
start_date = 1970  # Start date of your range
end_date = 1979  # End date of your range

decade1970 = cricket_data.loc[(cricket_data['year_only'] >= start_date) & (cricket_data['year_only'] <= end_date)]

decade1970
# Out:
#             Team 1       Team 2        Winner           Margin        Ground  \
# 4412  South Africa    Australia  South Africa         323 runs      Gqeberha
# 4413  South Africa    Australia  South Africa         307 runs  Johannesburg
# 4414  South Africa    Australia  South Africa  inns & 129 runs        Durban
# 4415  South Africa    Australia  South Africa         170 runs     Cape Town
# 2150       England        India         India        4 wickets      The Oval
# ...            ...          ...           ...              ...           ...
# 1763         India    Australia         India         153 runs        Kanpur
# 1760         India    Australia         India  inns & 100 runs      Wankhede
# 2136       England        India       England   inns & 83 runs    Birmingham
# 683        England     Pakistan       England          14 runs         Leeds
# 3209         India  West Indies   West Indies        9 wickets    Birmingham
#
#            Match Date   Scorecard Format       Year  year_only
# 4412   Mar 5-10, 1970  Test # 673  Test  1970-01-01       1970
# 4413  Feb 19-24, 1970  Test # 672  Test  1970-01-01       1970
# 4414    Feb 5-9, 1970  Test # 671  Test  1970-01-01       1970
# 4415  Jan 22-27, 1970  Test # 670  Test  1970-01-01       1970
# 2150  Aug 19-24, 1971  Test # 692  Test  1971-01-01       1971
# ...               ...         ...    ...        ...        ...
# 1763    Oct 2-7, 1979  Test # 857  Test  1979-01-01       1979
# 1760    Nov 3-7, 1979  Test # 860  Test  1979-01-01       1979
# 2136  Jul 12-16, 1979  Test # 851  Test  1979-01-01       1979
# 683      Jun 16, 1979    ODI # 71   ODI  1979-01-01       1979
# 3209      Jun 9, 1979    ODI # 61   ODI  1979-01-01       1979
#
# [184 rows x 10 columns]

# %%
start_date = 1960  # Start date of your range
end_date = 1969  # End date of your range

decade1960 = cricket_data.loc[(cricket_data['year_only'] >= start_date) & (cricket_data['year_only'] <= end_date)]

decade1960
# Out:
#            Team 1        Team 2       Winner          Margin         Ground  \
# 5926      England  South Africa      England  inns & 73 runs         Lord's
# 1784        India     Australia    Australia  inns & 55 runs        Chennai
# 5927      England  South Africa      England        100 runs     Birmingham
# 6375  West Indies       England      England        256 runs  Port of Spain
# 5925      England  South Africa      England       8 wickets     Nottingham
# ...           ...           ...          ...             ...            ...
# 7055  New Zealand   West Indies  New Zealand       6 wickets     Wellington
# 789      Pakistan   New Zealand  New Zealand       5 wickets         Lahore
# 2391        India   New Zealand        India         60 runs      Brabourne
# 1775        India     Australia    Australia       8 wickets      Brabourne
# 5698      England   New Zealand      England       8 wickets       The Oval
#
#               Match Date   Scorecard Format       Year  year_only
# 5926     Jun 23-27, 1960  Test # 493  Test  1960-01-01       1960
# 1784     Jan 13-17, 1960  Test # 486  Test  1960-01-01       1960
# 5927      Jun 9-14, 1960  Test # 492  Test  1960-01-01       1960
# 6375  Jan 28-Feb 3, 1960  Test # 488  Test  1960-01-01       1960
# 5925      Jul 7-11, 1960  Test # 494  Test  1960-01-01       1960
# ...                  ...         ...    ...        ...        ...
# 7055      Mar 7-11, 1969  Test # 651  Test  1969-01-01       1969
# 789   Oct 30-Nov 2, 1969  Test # 663  Test  1969-01-01       1969
# 2391     Sep 25-30, 1969  Test # 659  Test  1969-01-01       1969
# 1775       Nov 4-9, 1969  Test # 664  Test  1969-01-01       1969
# 5698     Aug 21-26, 1969  Test # 658  Test  1969-01-01       1969
#
# [97 rows x 10 columns]

# %%
start_date = 1950  # Start date of your range
end_date = 1959  # End date of your range

decade1950 = cricket_data.loc[(cricket_data['year_only'] >= start_date) & (cricket_data['year_only'] <= end_date)]

decade1950
# Out:
#             Team 1       Team 2       Winner           Margin        Ground  \
# 4439  South Africa    Australia    Australia        8 wickets     Cape Town
# 4436  South Africa    Australia    Australia  inns & 259 runs      Gqeberha
# 6387       England  West Indies  West Indies   inns & 56 runs      The Oval
# 6388       England  West Indies  West Indies       10 wickets    Nottingham
# 6389       England  West Indies  West Indies         326 runs        Lord's
# ...            ...          ...          ...              ...           ...
# 2169       England        India      England        8 wickets        Lord's
# 1786         India    Australia        India         119 runs        Kanpur
# 3054         India  West Indies  West Indies         295 runs       Chennai
# 3055         India  West Indies  West Indies  inns & 336 runs  Eden Gardens
# 1401      Pakistan  West Indies     Pakistan       10 wickets       Karachi
#
#                       Match Date   Scorecard Format       Year  year_only
# 4439  Dec 31, 1949 - Jan 4, 1950  Test # 319  Test  1950-01-01       1950
# 4436               Mar 3-6, 1950  Test # 322  Test  1950-01-01       1950
# 6387             Aug 12-16, 1950  Test # 326  Test  1950-01-01       1950
# 6388             Jul 20-25, 1950  Test # 325  Test  1950-01-01       1950
# 6389             Jun 24-29, 1950  Test # 324  Test  1950-01-01       1950
# ...                          ...         ...    ...        ...        ...
# 2169             Jun 18-20, 1959  Test # 475  Test  1959-01-01       1959
# 1786             Dec 19-24, 1959  Test # 483  Test  1959-01-01       1959
# 3054             Jan 21-26, 1959  Test # 465  Test  1959-01-01       1959
# 3055  Dec 31, 1958 - Jan 4, 1959  Test # 463  Test  1959-01-01       1959
# 1401             Feb 20-25, 1959  Test # 469  Test  1959-01-01       1959
#
# [114 rows x 10 columns]

# %%
cricket_data["Winner"].value_counts().plot(kind = "bar")
plt.xlabel("Teams")
plt.ylabel("Number of times match won ")
plt.title("Teams & Number of Matches Won (All Time)", fontsize = 20)
plt.show()

# %%
decade2020["Winner"].value_counts().plot(kind = "bar")
plt.xlabel("Teams")
plt.ylabel("Number of times match won ")
plt.title("Teams & Number of Matches Won (2020-2025)", fontsize = 20)
plt.show()

# %%
decade2010["Winner"].value_counts().plot(kind = "bar")
plt.xlabel("Teams")
plt.ylabel("Number of times match won ")
plt.title("Teams & Number of Matches Won (2010 - 2019)", fontsize = 20)
plt.show()

# %%
decade2000["Winner"].value_counts().plot(kind = "bar")
plt.xlabel("Teams")
plt.ylabel("Number of times match won ")
plt.title("Teams & Number of Matches Won (2000 - 2009)", fontsize = 20)
plt.show()

# %%
decade1990["Winner"].value_counts().plot(kind = "bar")
plt.xlabel("Teams")
plt.ylabel("Number of times match won ")
plt.title("Teams & Number of Matches Won (1990 - 1999)", fontsize = 20)
plt.show()

# %%
decade1980["Winner"].value_counts().plot(kind = "bar")
plt.xlabel("Teams")
plt.ylabel("Number of times match won ")
plt.title("Teams & Number of Matches Won (1980 - 1989)", fontsize = 20)
plt.show()

# %%
decade1970["Winner"].value_counts().plot(kind = "bar")
plt.xlabel("Teams")
plt.ylabel("Number of times match won ")
plt.title("Teams & Number of Matches Won (1970 - 1979)", fontsize = 20)
plt.show()

# %%
decade1960["Winner"].value_counts().plot(kind = "bar")
plt.xlabel("Teams")
plt.ylabel("Number of times match won ")
plt.title("Teams & Number of Matches Won (1960 - 1969)", fontsize = 20)
plt.show()

# %%
plt.show()
decade1950["Winner"].value_counts().plot(kind="bar")
plt.xlabel("Teams")
plt.ylabel("Number of times match won ")
plt.title("Teams & Number of Matches Won (1950 - 1959)", fontsize=20)
plt.show()
